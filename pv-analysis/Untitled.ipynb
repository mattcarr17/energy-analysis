# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('../data/data1.csv').drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
df.head()
# Out:
#     zcta    state        lat        long  average_household_income  \
# 0  85610  Arizona  31.744197  109.722324              53713.747228
# 1  85614  Arizona  31.814301  110.919400              67347.031441
# 2  85624  Arizona  31.504971  110.692999              56508.955224
# 3  85629  Arizona  31.917838  111.019035              91646.185302
# 4  85630  Arizona  31.886572  110.181046              57186.339381
#
#    mean_household_income_lowest_quintile  \
# 0                                15735.0
# 1                                15092.0
# 2                                12085.0
# 3                                24218.0
# 4                                 6123.0
#
#    mean_household_income_second_quintile  \
# 0                                28976.0
# 1                                33942.0
# 2                                26596.0
# 3                                55100.0
# 4                                16639.0
#
#    mean_household_income_third_quintile  \
# ...

# %%
df['long'] = df['long'] * -1

# %% [markdown]
# Just want to explore some of the core visualizations I want in the dashboard. Focus is on exploring the overall system. How the various sub-systems affect each other and make up the overall system.

# %%
df[['num_systems', 'total_capacity', 'mean_system_size', 'median_system_size']].replace(to_replace=np.nan, value=0, inplace=True)
# Out:
# /Users/mattcarr/opt/anaconda3/envs/ghg-analysis/lib/python3.9/site-packages/pandas/core/frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df = df.loc[df['household_count'] > 0]

# %%
df['solar_density'] = df['total_capacity'] / (df['household_count'] / 1000)

# %%
df.columns
# Out:
# Index(['zcta', 'state', 'lat', 'long', 'average_household_income',
#        'mean_household_income_lowest_quintile',
#        'mean_household_income_second_quintile',
#        'mean_household_income_third_quintile',
#        'mean_household_income_fourth_quintile',
#        'mean_household_income_highest_quintile',
#        ...
#        'frost_days', 'earth_temp_amplitude', 'solar_azimuth_angle',
#        'num_systems', 'total_capacity', 'mean_system_size',
#        'median_system_size', 'num_incentives', 'num_policies',
#        'solar_density'],
#       dtype='object', length=107)
